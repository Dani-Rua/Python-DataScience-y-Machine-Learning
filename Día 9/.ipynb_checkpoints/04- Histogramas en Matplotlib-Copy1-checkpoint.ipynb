# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Esto permite no poner al final el shown sino con solo poner un ; muestra el gráfico
# %matplotlib inline

# %%
ruta = r"C:\Users\Hogar\Desktop\Python-DataScience-y-Machine-Learning\Recursos\Ventas.csv"
df = pd.read_csv(ruta)
df
# Out:
#          Fecha    Producto  Cantidad  Precio Unitario  Total Venta
# 0    1/17/2023  Electrónic         7              200         1400
# 1     9/1/2023  Electrónic         8              200         1600
# 2    7/29/2023    Juguetes         3               30           90
# 3    10/4/2023   Alimentos         4               10           40
# 4    2/28/2023  Electrónic         6              200         1200
# ..         ...         ...       ...              ...          ...
# 995  4/27/2023   Alimentos         2               10           20
# 996   6/9/2023        Ropa        10               50          500
# 997  8/21/2023   Alimentos         8               10           80
# 998  3/28/2023  Electrónic         6              200         1200
# 999   3/7/2023  Electrónic         4              200          800
#
# [1000 rows x 5 columns]

# %%
# Cómo crear un hisotgrama
plt.hist(df["Producto"]);

# %%
# Crea un array de números aleatorios de 1 a 1000
numeros = np.random.randn(1000)
numeros
# Out:
# array([-1.13581400e-01, -5.21202038e-01, -8.27314789e-01, -3.75150880e-01,
#         8.61494860e-01, -2.20542079e+00, -7.69842620e-01, -6.77777624e-02,
#        -2.21744966e+00, -7.36085846e-01, -1.57686460e+00, -3.80338594e-01,
#        -7.62652141e-03, -9.86982971e-01,  1.85784311e-03,  1.19322215e+00,
#         3.32068242e-01, -5.16460471e-01, -4.59871664e-01,  1.51665142e+00,
#         6.81790327e-01,  7.14488178e-01, -5.54256756e-01, -1.95608242e+00,
#        -8.66853246e-01, -1.20748557e+00,  9.43794640e-01,  5.74463013e-01,
#         8.58068166e-01,  2.16241928e-01, -1.87753587e+00, -7.94261597e-01,
#         5.37537621e-01, -1.94452420e-01,  1.25548864e+00, -5.95882288e-01,
#        -1.07053169e-01, -3.24428332e-01,  1.63068192e-01,  2.45239912e-02,
#         1.61562455e+00, -1.07104901e+00,  3.52355149e-01, -3.55265205e-01,
#         1.86651722e-01,  1.06098273e+00, -8.29614559e-01,  3.18646250e-01,
# ...

# %%
plt.hist(numeros);

# %%
# Usamos bins para poner en este caso 40 columnas
plt.hist(numeros, bins=40);

# %%
# Alpha nos permite establecer la transparencia
plt.hist(numeros, bins=40, alpha=0.5);

# %%
# Color permite cambiar el color
plt.hist(numeros, bins=40, alpha=0.5, color="red");

# %%
# color de borde con edgecolor
plt.hist(numeros, bins=40, alpha=0.5, color="red", edgecolor="green");

# %%
# Tipo de histograma con histtype
plt.hist(numeros, bins=40, alpha=0.5, color="red", edgecolor="green", histtype="step");

# %%
# Exponer varios histogramas en un mismo axes
x1 = np.random.randn(1000)
x2 = np.random.randn(500)
x3 = np.random.randn(100)

plt.hist(x1, histtype='stepfilled', alpha=0.3, bins=40);
plt.hist(x2, histtype='stepfilled', alpha=0.3, bins=40);
plt.hist(x3, histtype='stepfilled', alpha=0.3, bins=40);

# %%
import matplotlib.pyplot as plt

# Esto permite no poner al final el shown sino con solo poner un ; muestra el gráfico
# %matplotlib inline

# %%
numeros = [4,3,4,10,6,7]

# %%
# Plot sirve para crear un gráfico y savefig para guardar la imagen
plt.plot(numeros)
plt.savefig("mi_grafico.png");

# Show para mostrar el gráfico
#plt.show()

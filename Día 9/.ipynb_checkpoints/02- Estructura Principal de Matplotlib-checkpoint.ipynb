# %%
import matplotlib.pyplot as plt

# Esto permite no poner al final el shown sino con solo poner un ; muestra el gráfico
# %matplotlib inline

# %%
numeros = [4,3,4,10,6,7]
plt.plot(numeros);

# %%
#Cambiar de color en el figure
plt.figure(facecolor="orange")
plt.plot(numeros);

# %%
# Crear mas de 1 gráfico (Axes)
plt.subplots(ncols=2, nrows=2)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
# para capturar en variables esos Axes
fig, axs = plt.subplots(ncols=2, nrows=2)

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(axs)
# Out:
# numpy.ndarray

# %%
# Capturar la primera fila
axs[0]
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
axs[0][0]
# Out:
# <Axes: >

# %%
type(axs[0][0])
# Out:
# matplotlib.axes._axes.Axes

# %%
# Axes es un objeto de matplotlib
axes1 = axs[0][0]

# %%
axes1.title
# Out:
# Text(0.5, 1.0, '')

# %% [markdown]
# # Proyecto del Día 3: Analizador de Texto
#
# Este proyecto tiene como objetivo aplicar los conceptos aprendidos sobre strings, input, indexación y formateo de strings en Python. El programa permitirá al usuario ingresar un texto y luego elegir realizar diversas operaciones de análisis sobre ese texto.
#
# ## Consigna
# Vas a crear un programa que le pida al usuario que ingrese un texto de al menos 10 palabras. Tu programa va a procesar ese texto, lo va a procesar, y le va a devolver un análisis detallado, que incluya:
# 1. Contar el número total de caracteres en el texto
# 2. Contar el número de caracteres sin incluir los espacios
# 3. Contar la cantidad de vocales que hay en el texto
# 4. Contar el número total de palabras en el texto ingresado
#
# **nota**: para resolver los siguientes items, deberás investigar otros métodos de strings que no hemos visto. Recuerda valerte de *type*, *dir* y *help*
#
# 5. Eliminar la primera palabra
# 6. Reemplazar todos los espacios por guiones medios (-)
# 8. Cambia las mayúsculas a minúsculas y las minúsculas a mayúsculas
#
# Al finalizar el procesamiento, se imprimirán 8 cadenas literales mostrando los resultados del análisis (una cadena por cada resultado).
# <br>
# <br>
# <br>

# %% [markdown]
# ### Resolución
#
# Ingreso del usuario:

# %%
texto = input("Ingrese un texto con almenos 10 palabras")
texto
# Out:
# Ingrese un texto con almenos 10 palabras Hola soy Daniel y me gusta aprender python, y quiero ser el mejor
# 'Hola soy Daniel y me gusta aprender python, y quiero ser el mejor'

# %% [markdown]
# 1. Contar el número total de caracteres en el texto

# %%
contar_caracteres = len(texto)
contar_caracteres
# Out:
# 65

# %% [markdown]
# 2. Contar el número de caracteres sin incluir los espacios

# %%
contar_caract_sin_espacio = len(texto.replace(" ", ""))
contar_caract_sin_espacio
# Out:
# 53

# %% [markdown]
# 3. Contar la cantidad de vocales que hay en el texto

# %%
a = texto.count("a")
e = texto.count("e")
i = texto.count("i")
o = texto.count("o")
u = texto.count("u")
cantidad_total_vocales = a + e + i + o + u
cantidad_total_vocales
# Out:
# 21

# %% [markdown]
# 4. Contar el número total de palabras en el texto ingresado

# %%
contar_caract_sin_espacio = len(texto.split(" "))
contar_caract_sin_espacio
# Out:
# 13

# %% [markdown]
# 5. Eliminar la primera palabra

# %%
encontrar_palabra = texto.find(" ")
eliminar_palabra = texto[encontrar_palabra + 1:]
eliminar_palabra
# Out:
# 'soy Daniel y me gusta aprender python, y quiero ser el mejor'

# %% [markdown]
# 6. Reemplazar todos los espacios por guiones medios (-)

# %%
reemplaza_espacios_por_guiones = texto.replace(" ", "-")
reemplaza_espacios_por_guiones
# Out:
# 'Hola-soy-Daniel-y-me-gusta-aprender-python,-y-quiero-ser-el-mejor'

# %% [markdown]
# 7. Cambia las mayúsculas a minúsculas y las minúsculas a mayúsculas

# %%
cambiar_minu_mayu = texto.swapcase()
cambiar_minu_mayu
# Out:
# 'hOLA SOY dANIEL Y ME GUSTA APRENDER PYTHON, Y QUIERO SER EL MEJOR'

# %% [markdown]
# Muéstrale al usuario los resultados del análisis de su texto.

# %%
print(texto)
print("")
print(contar_caracteres)
print("")
print(contar_caract_sin_espacio)
print("")
print(cantidad_total_vocales)
print("")
print(contar_caract_sin_espacio)
print("")
print(eliminar_palabra)
print("")
print(reemplaza_espacios_por_guiones)
print("")
print(cambiar_minu_mayu)
print("")
print("Gracias por hacer esto posible y seguir adelante con tú sueño")
# Out:
# Hola soy Daniel y me gusta aprender python, y quiero ser el mejor
#
# 65
#
# 53
#
# 21
#
# 53
#
#  soy Daniel y me gusta aprender python, y quiero ser el mejor
#
# Hola-soy-Daniel-y-me-gusta-aprender-python,-y-quiero-ser-el-mejor
#
# hOLA SOY dANIEL Y ME GUSTA APRENDER PYTHON, Y QUIERO SER EL MEJOR
#
# Gracias por hacer esto posible y seguir adelante con tú sueño

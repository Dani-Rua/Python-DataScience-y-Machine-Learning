# %%
import pandas as pd

serie = pd.Series([5, 10, 15, 20, 25])
serie
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64

# %%
promedio = serie.mean()
print(f'El promedio de los númemos es {promedio}')
# Out:
# El promedio de los númemos es 15.0

# %%
total = serie.sum()
total
# Out:
# np.int64(75)

# %%
num_max = serie.max()
num_max
# Out:
# 25

# %%
num_min = serie.min()
num_min
# Out:
# 5
